# %% [markdown]
# ## This notebook works on Word Embeddings using Keras (from scratch, fine tune learned embeddings, look up embeddings)

# %% [markdown]
# ### Import the libraries and define the arguments

# %%
# import the necessary libraries
from keras.layers.core import Dense, Activation, Dropout, SpatialDropout1D 
from keras.layers.convolutional import Conv1D
from keras.layers.embeddings import Embedding
from keras.layers.pooling import GlobalMaxPooling1D
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.sequence import pad_sequences
import keras.backend as K

import nltk
import collections
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split

np.random.seed(42)

INPUT_FILE = "/Users/tkmacl9/Desktop/FastAIDLCourse/umich_sentiment_dataset/train.txt"
VOCAB_SIZE = 5000
EMBEDDING_SIZE = 100
NUM_FILTERS=256
NUM_WORDS = 3
BATCH_SIZE = 64
NUM_EPOCHS = 20

# %% [markdown]
# ### Learn Embeddings from Scratch

# %%
# create our vocablary of most frequent words from the corpus
counter = collections.Counter()
fin = open(INPUT_FILE, 'r')
maxlen = 0
i = 0
for line in fin:
    sent = line.strip().split("\t")[1]
    words = [x.lower() for x in nltk.word_tokenize(sent)]
    if len(words) > maxlen:
        maxlen = len(words)
    for word in words:
        counter[word] += 1
fin.close()

# create the word indexes and the reverse indexes for the words
word2index = collections.defaultdict(int)
for wid, word in enumerate(counter.most_common(VOCAB_SIZE)):
    word2index[word[0]] = wid +1
vocab_size = len(word2index) + 1
index2word = {v:k for k,v in word2index.items()}
print(word2index)
print("")
print(index2word)
# Out:
# defaultdict(<class 'int'>, {'disliked': 541, 'they': 319, 'page': 648, '``': 35, 'groaning': 274, 'before': 367, 'mindless': 970, 'goes': 971, 'crap': 449, 'tournament..': 972, 'homosexuality': 227, 'was': 18, 'so': 32, 'aniwae': 973, 'impressive': 974, 'otp': 975, 'education': 649, 'chinese': 650, 'playing': 535, 'â€': 651, 'chick': 976, 'during': 539, 'hermione': 977, 'possibly': 978, 'correct': 1591, 'all': 310, 'adore': 979, 'few': 448, 'first': 114, "was'harry": 981, 'find': 983, 'problem': 654, 'half': 484, 'around': 183, 'weeeellllllll': 1088, 'im': 450, 'talking': 398, 'vigor': 228, 'criticized': 987, 'touching': 988, 'industry': 681, 'suck': 51, 'must': 451, 'well': 127, 'jackson': 1049, 'erm': 536, 'didnt': 655, '2': 117, 'visually': 993, 'literary': 994, 'anyways': 537, 'mang': 995, 'xd': 996, 'give': 452, 'german..': 998, 'reads': 999, 'bolsters': 1000, 'iii-sucks': 1001, 'lit': 538, 'exhausted': 1002, 'lines': 1003, 'diana': 1005, 'future': 656, 'heard': 133, 'indoctrinate': 1189, 'infuser': 698, 'christmas..': 1656, 'saturday': 696, 'you': 41, 'france': 1694, 'the': 4, 'try': 386, 'blog': 1010, 'won': 454, 'requested': 658, 'impossible..': 659, 'ground': 1011, 'old': 660, 'franchise': 707, 'people': 75, 'ever': 135, 'rachel': 1013, 'asking': 661, 'blogbacklinktitle': 1014, 'wesley': 662, 'though': 314, 'may': 348, 'final': 663, '-yes': 1017, 'boring': 151, 'gosh': 1019, 'decided': 485, 'ur': 1020, 'gayer': 1021, 'mall': 1022, 'versa': 1023, 'reaction': 722, 'sense': 652, 'gettting': 1025, 'fowl': 1026, 'station': 229, 'main': 191, 'deals': 2198, 'barry': 1027, 'crack': 1028, 'colourfully': 664, 'started': 1029, 'animated': 1030, 'butt': 732, 'discovered': 1032, 'icons..': 1033, 'record': 682, 'is': 16, 'explaination': 1035, "saying'harry": 1396, 'code-sucked': 666, 'allegedly': 1037, 'messy': 1038, 'delicious': 1039, 'written': 667, 'cinema': 1040, 'we': 43, 'classic': 1042, 'following': 1043, 'silly': 1044, 'release': 1045, 'genres': 1046, 'impossible-tom': 1047, 'enjoyment': 1048, 'nd': 2120, 'mybutthole': 1050, 'theatan': 1051, 'hands': 576, 'archive': 1052, 'urls': 1053, 'let': 540, 'played': 486, 'wants': 1054, 'making': 156, 'fill': 1055, 'girls': 669, 'talkin': 1056, 'crash': 368, 'easy': 1057, 'hips': 230, 'requim': 1058, 'demons': 417, '00': 1513, 'films': 487, 'picturesque': 1061, 'shell': 1062, 'talk': 369, 'quirky': 1063, 'despise': 1064, 'belong': 1065, 'pull': 1066, 'x3-good': 1068, 'keep': 1069, 'vault': 2119, 'bootlegged': 1071, 'stinkin': 1664, 'emo-mound': 2118, 'oceanwalk': 1073, 'mostly': 984, 'possum': 1075, 'biased': 671, 'pink': 1136, 'chronological': 1076, 'deserved': 672, 'sister': 1665, 'leah': 231, 'panties': 1883, 'nc-17': 542, 'theres': 1078, 'um': 1079, 'love': 15, 'search': 1080, 'apparently': 456, 'budget': 1081, 'never': 157, 'het': 674, 'relaxed': 2123, 'talks': 1427, 'specifically': 1083, 'daddy': 985, 'witha': 1789, 'grand': 1086, 'low': 2307, 'says': 171, 'dvd': 1198, 'along': 544, 'off': 357, 'moving': 1087, 'luau': 1089, 'actually': 340, 'compared': 866, 'fall': 675, 'definately': 676, '2..': 2032, 'had': 321, 'now': 324, 'turned': 205, 'race': 1091, '*': 322, 'reality': 215, 'cold': 677, 'bonkers': 233, 'crazy': 206, 'hoover': 678, 'itself': 1094, 'villains': 1095, 'including': 1096, 'guys': 679, 'hot': 813, 'considered': 1098, 'happen': 969, 'terrible': 86, 'onto': 989, 'delayed': 2117, 'ca': 148, 'although': 929, 'equally': 729, 'trousers': 273, 'two': 349, 'â’': 1102, 'scent': 1103, 'nature': 1104, 'minutes': 545, 'dynamite': 1105, 'screening': 1106, 'egg': 683, 'teevee': 1108, 'dorks': 1109, 'daniel': 192, 'bless': 1110, 'kicked': 1111, 'shes': 1112, 'times': 400, 'theme': 370, 'ideas': 1113, 'does': 145, 'seem': 1115, 'both': 155, 'degraw': 2128, "'re": 161, 'oreos': 1117, 'outshines': 268, "'yeah": 234, 'point': 684, 'food': 546, 'yahoo': 1119, 'davinci': 1120, "'s": 27, 'against': 934, 'style': 1123, 'defensive': 1124, 'john': 488, 'ok': 93, 'not': 71, 'jake': 547, ' ...
#
# {1: 'i', 2: ',', 3: '.', 4: 'the', 5: 'and', 6: '!', 7: 'harry', 8: 'vinci', 9: 'da', 10: 'brokeback', 11: 'code', 12: 'mountain', 13: 'potter', 14: '...', 15: 'love', 16: 'is', 17: 'a', 18: 'was', 19: 'mission', 20: 'impossible', 21: 'awesome', 22: 'like', 23: 'it', 24: 'to', 25: 'movie', 26: 'that', 27: "'s", 28: 'because', 29: 'sucks', 30: 'hate', 31: 'sucked', 32: 'so', 33: 'as', 34: 'my', 35: '``', 36: 'much', 37: 'of', 38: 'really', 39: 'movies', 40: 'stupid', 41: 'you', 42: 'down', 43: 'we', 44: 'but', 45: 'be', 46: 'with', 47: 'just', 48: 'one', 49: 'potter..', 50: 'know', 51: 'suck', 52: 'out', 53: '3', 54: 'who', 55: 'or', 56: '/', 57: 'am', 58: 'loved', 59: 'want', 60: 'into', 61: 'which', 62: 'right', 63: 'for', 64: 'an', 65: "n't", 66: 'this', 67: 'me', 68: ':', 69: 'are', 70: 'think', 71: 'not', 72: 'how', 73: 'if', 74: 'depressing', 75: 'people', 76: 'his', 77: 'would', 78: 'up', 79: 'reading', 80: 'why', 81: 'series', 82: 'there', 83: 'only', 84: 'in', 85: 'fucking', 86: 'terrible', 87: 'she', 88: 'story', 89: 'oh', 90: 'being', 91: '..', 92: 'left', 93: 'ok', 94: 'guy', 95: 'here', 96: 'start', 97: 'felicia', 98: '(', 99: 'have', 100: 'book', 101: 'about', 102: 'beautiful', 103: 'good', 104: 'too', 105: 'also', 106: 'on', 107: 'went', 108: 'do', 109: 'read', 110: 'at', 111: 'then', 112: 'can', 113: 'saw', 114: 'first', 115: 'by', 116: 'tom', 117: '2', 118: 'most', 119: 'more', 120: 'thought', 121: 'from', 122: 'absolutely', 123: 'liked', 124: 'way', 125: 'horrible', 126: 'still', 127: 'well', 128: 'time', 129: 'he', 130: 'when', 131: 'got', 132: 'awesome..', 133: 'heard', 134: 'big', 135: 'ever', 136: 'going', 137: 'watch', 138: 'film', 139: 'were', 140: 'what', 141: 'great', 142: 'things', 143: 'such', 144: 'better', 145: 'does', 146: 'said', 147: 'last', 148: 'ca', 149: '=', 150: '?', 151: 'boring', 152: 'gay', 153: 'yeah', 154: 'watching', 155: 'both', 156: 'making', 157: 'never', 158: 'wait', 159: 'again', 160: 'man', 161: "'re", 162: 'these', 163: 'â€™', 164: 'same', 165: 'friday', 166: 'sucked..', 167: 'always', 168: 'person', 169: 'excellent', 170: 'friends', 171: 'says', 172: 'opinion', 173: 'anyone', 174: 'cool', 175: 'na', 176: 'cock', 177: 'rocks', 178: 'him', 179: 'make', 180: 'take', 181: 'side', 182: 'anyway', 183: 'around', 184: 'where', 185: 's', 186: 'worth', 187: 'mom', 188: 'knows', 189: 'fun', 190: 'either', 191: 'main', 192: 'daniel', 193: 'review', 194: 'freakin', 195: 'wanted', 196: 'luv', 197: 'dad', 198: 'care', 199: 'b', 200: 'character', 201: 'thats', 202: 'community', 203: 'hates', 204: 'place', 205: 'turned', 206: 'crazy', 207: 'head', 208: 'type', 209: 'cowboy', 210: 'past', 211: 'table', 212: 'dies', 213: 'snuck', 214: 'seen..', 215: 'reality', 216: 'becoming', 217: 'stand', 218: 'bitch', 219: 'awards', 220: 'needs', 221: 'soo', 222: 'hat', 223: 'gon', 224: 'acceptable', 225: 'horrible..', 226: 'begin', 227: 'homosexuality', 228: 'vigor', 229: 'station', 230: 'hips', 231: 'leah', 232: 'bobbypin', 233: 'bonkers', 234: "'yeah", 235: 'acne', 236: 'goin', 237: 'differently', 238: 'panting', 239: 'gin', 240: 'count', 241: 'noises', 242: 'likes', 243: 'deep', 244: 'laughed', 245: 'dudeee', 246: 'jokes..', 247: 'hella', 248: 'plain', 249: 'black', 250: 'serious', 251: 'virgin', 252: 'slap', 253: 'coz', 254: 'reminded', 255: 'insanely', 256: 'eyre', 257: 'hill', 258: 'jane', 259: 'catcher', 260: 'silent', 261: 'zen', 262: 'aching', 263: 'helped', 264: 'sit', 265: 'draco', 266: 'gary', 267: 'letting', 268: 'outshines', 269: 'kirsten', 270: 'stars', 271: 'escapades', 272: 'joining', 273: 'trousers', 274: 'groaning', 275: 'tye', 276: 'grabs', 277: 'dash', 278: 'blonds', 279: 'hung', 280: 'wotshisface', 281: 'desperately', 282: 'material', 283: 'kate', 284: 'bye..', 285: "love'the", 286: "'..", 287: 'whimpering', 288: 'profound', 289: 'throat', 290: 'dragged', 291: 'suicides', 292: 'quiz', 293: 'combining', 294: 'mtv', 295: 'despised', 296: 'sentry', 297: 'malfoy', 298: 'cleaning', 299: 'key ...

# %% [markdown]
# ### Now pad the sentences to the maxlength and create the dataset for splitting
