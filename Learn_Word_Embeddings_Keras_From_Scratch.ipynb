# %% [markdown]
# ## This notebook works on Word Embeddings using Keras (from scratch)

# %% [markdown]
# ### Import the libraries and define the arguments

# %%
# import the necessary libraries
from keras.layers.core import Dense, Activation, Dropout, SpatialDropout1D 
from keras.layers.convolutional import Conv1D
from keras.layers.embeddings import Embedding
from keras.layers.pooling import GlobalMaxPooling1D
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.sequence import pad_sequences
import keras.backend as K

import nltk
import collections
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
# %matplotlib inline

np.random.seed(42)

INPUT_FILE = "/Users/tkmacl9/Desktop/FastAIDLCourse/datasets/umich_sentiment_dataset/train.txt"
VOCAB_SIZE = 5000
EMBEDDING_SIZE = 100
NUM_FILTERS=256
NUM_WORDS = 3
BATCH_SIZE = 64
NUM_EPOCHS = 20
DROPOUT_RATE = float(0.2)

# %% [markdown]
# ### Learn Embeddings from Scratch

# %%
# create our vocablary of most frequent words from the corpus
counter = collections.Counter()
fin = open(INPUT_FILE, 'r')
maxlen = 0
i = 0
for line in fin:
    sent = line.strip().split("\t")[1]
    words = [x.lower() for x in nltk.word_tokenize(sent)]
    if len(words) > maxlen:
        maxlen = len(words)
    for word in words:
        counter[word] += 1
fin.close()

# create the word indexes and the reverse indexes for the words
word2index = collections.defaultdict(int)
for wid, word in enumerate(counter.most_common(VOCAB_SIZE)):
    word2index[word[0]] = wid +1
vocab_size = len(word2index) + 1
index2word = {v:k for k,v in word2index.items()}
print(word2index)
print("")
print(index2word)
# Out:
# defaultdict(<class 'int'>, {'flat': 969, 'ridiculous': 2103, 'depressing': 74, 'joining': 227, 'fyi-mission': 973, 'jesus': 500, 'included': 974, 'been': 363, 'weird': 976, 'cowboy': 205, 'esther': 2300, 'scenario': 977, 'mcmurtry': 978, 'patirot': 979, 'eek': 980, 'ideas': 1251, 'summer': 981, 'fanfiction': 574, 'deal': 535, 'begin': 206, 'heart': 536, 'home': 648, 'totally': 398, 'tickets': 649, 'sit': 270, 'code-illustrated': 1176, 'gavin': 982, 'love': 15, 'knew': 650, 'true': 635, 'combining': 228, 'german..': 985, 'score': 651, 'boring': 151, 'phrase': 987, 'fill': 1092, 'gosh': 989, 'more..': 990, 'slash': 991, 'friend': 652, 'wan': 528, 'husband': 1897, 'bogus': 448, 'families': 994, 'oreos': 995, 'night': 367, 'hermione': 996, 'saw': 113, 'gon': 208, 'off': 357, 'concocted': 997, 'omg': 484, 'gin': 229, '-after': 998, "mountain'is": 999, 'demons': 418, 'controversy': 654, 'afraid': 1000, 'probably': 449, 'amazing..': 1001, 'effort': 1002, 'predictable': 1175, 'crusade': 1004, 'awesome..': 129, 'yeah-i': 2281, '<': 334, 'desperately': 230, 'thinking': 399, 'laughed': 250, 'otp': 1635, 'comment': 537, 'wrote': 1143, 'pegg': 1009, 'keys': 231, 'rant': 538, 'kudos': 1186, 'sivullinen': 658, 'caribbean': 1578, 'transamerica': 2293, 'astonishingly': 1011, 'spend': 1871, 'eragon': 539, 'kat-tun': 1013, 'cowan': 1315, '+': 540, 'spells': 1016, 'kelse': 1017, 'virgin': 233, 'sick': 450, 'georgia': 523, 'basket': 1873, 'rocks..': 2244, 'folows': 1881, 'please': 661, 'remix..': 1018, 'cocktail': 662, 'weekends': 2113, 'looks': 386, 'while': 387, 'mckellen': 1021, 'book-i': 1874, 'ones..': 1022, 'besides': 541, 'half': 485, 'bentlys': 1023, 'escapades': 234, 'keeps': 1024, 'between': 542, 'respect': 663, '517,648': 1027, 'whole': 543, 'incredibly': 486, 'though': 314, 'brown': 554, 'abortion': 1029, 'keep': 1030, 'conclusion': 573, '10pm': 1032, 'fabricated': 1033, 'truly-awful': 1034, 'dvd': 1035, 'hero': 664, 'meeting': 665, 'reopened': 1037, 'maybe': 666, 'phone': 1038, 'burbank': 1039, 'draw': 667, 'catch': 668, 'apparently': 456, 'experience': 1041, 'still': 125, 'spin': 1043, 'lubb': 235, 'funniest': 669, 'vs': 1044, '(': 98, 'google': 1046, 'rachel': 1047, 'relaxed': 1048, 'never': 156, 'problem': 670, 'obnoxious': 671, 'dies': 214, 'friends': 165, 'state': 1412, 'clearly': 1051, 'if': 73, 'forgotten': 672, "'s": 27, 'including': 1647, 'runner': 1052, 'my': 34, '31st': 1413, 'mountain-watched': 1053, 'firstly': 1054, 'infuser': 673, 'your': 368, 'edition': 1055, 'cuz': 544, 'rings': 471, 'meganpenworthy': 1057, 'chronological': 1058, 'longer': 1059, 'portuguese': 1414, 'ass': 316, 'before': 369, 'jackson': 1189, 'happiness': 1775, 'tech': 1063, 've': 1650, 'gym': 2282, 'hogwarts': 674, 'figure': 1064, 'freshman': 1065, '``': 35, 'facile': 1124, 'â€™': 161, 'â’': 1067, 'monsters': 1015, 'comparrison': 2121, 'ta': 488, 'discussing': 1068, 'diana': 1271, '.': 3, 'deep': 291, 'year': 445, 'plain': 276, 'truly': 1071, 'big': 133, 'âµâª': 1072, 'lost': 419, 'easy': 1609, 'sucked..': 166, 'impossible': 20, 'perfect': 1415, 'drain': 1074, 'erin': 1887, 'revise': 1619, 'jane': 239, 'wotshisface': 240, 'disappointing': 1078, 'better': 142, 'you..': 1079, '..-have': 2047, 'was': 18, 'matters': 1081, 'denial': 1082, '@': 1083, 'community': 191, 'christianity': 1084, 'seen': 344, 'woo': 489, 'zen': 242, 'also': 104, 'anywhere': 1086, 'reader': 1087, 'tells': 1088, 'evil..': 613, 'gays': 1089, 'finshed': 1090, '&': 370, 'poorly': 1091, 'guys..': 1916, 'melbourne': 1093, 'putting': 681, 'interest': 2133, 'life': 389, 'quizzes': 682, 'burnt': 1094, 'consumed': 1194, 'man': 157, 'balls': 340, 'beatles': 1096, 'throw': 1097, 'police': 2029, 'btw': 683, 'erm': 545, 'ian': 1658, 'childishly': 1099, 'lord': 451, 'stupidest': 1100, 'wherever': 2243, 'crystal': 1101, 'confess': 2142, 'question': 684, 'quite': 420, 'debates..': 1978, '3..': 491, 'ball': 2325, 'mindless': 2045, 'likes': 292, 'diversity': 1104, 'mi': 1105, 'going': 135, '10': 845,  ...
#
# {1: 'i', 2: ',', 3: '.', 4: 'the', 5: 'and', 6: '!', 7: 'harry', 8: 'vinci', 9: 'da', 10: 'brokeback', 11: 'code', 12: 'mountain', 13: 'potter', 14: '...', 15: 'love', 16: 'is', 17: 'a', 18: 'was', 19: 'mission', 20: 'impossible', 21: 'awesome', 22: 'like', 23: 'it', 24: 'to', 25: 'movie', 26: 'that', 27: "'s", 28: 'because', 29: 'sucks', 30: 'hate', 31: 'sucked', 32: 'so', 33: 'as', 34: 'my', 35: '``', 36: 'much', 37: 'of', 38: 'really', 39: 'movies', 40: 'stupid', 41: 'you', 42: 'down', 43: 'but', 44: 'we', 45: 'be', 46: 'with', 47: 'just', 48: 'one', 49: 'know', 50: 'potter..', 51: 'suck', 52: 'out', 53: '3', 54: '/', 55: 'who', 56: 'or', 57: 'am', 58: 'loved', 59: 'want', 60: 'into', 61: 'which', 62: 'right', 63: 'for', 64: 'an', 65: "n't", 66: 'this', 67: 'me', 68: ':', 69: 'are', 70: 'think', 71: 'not', 72: 'how', 73: 'if', 74: 'depressing', 75: 'people', 76: 'his', 77: 'would', 78: 'up', 79: 'reading', 80: 'why', 81: 'series', 82: 'there', 83: 'only', 84: 'in', 85: 'fucking', 86: 'terrible', 87: 'she', 88: 'oh', 89: 'story', 90: 'being', 91: '..', 92: 'left', 93: 'ok', 94: 'here', 95: 'guy', 96: 'start', 97: 'felicia', 98: '(', 99: 'have', 100: 'book', 101: 'about', 102: 'beautiful', 103: 'good', 104: 'also', 105: 'too', 106: 'on', 107: 'went', 108: 'do', 109: 'read', 110: 'at', 111: 'can', 112: 'then', 113: 'saw', 114: 'first', 115: 'by', 116: 'tom', 117: 'thought', 118: 'more', 119: '2', 120: 'most', 121: 'absolutely', 122: 'liked', 123: 'way', 124: 'from', 125: 'still', 126: 'horrible', 127: 'time', 128: 'well', 129: 'awesome..', 130: 'he', 131: 'when', 132: 'got', 133: 'big', 134: 'heard', 135: 'going', 136: 'film', 137: 'ever', 138: 'watch', 139: 'what', 140: 'were', 141: 'great', 142: 'better', 143: 'things', 144: 'such', 145: 'said', 146: 'last', 147: 'does', 148: '?', 149: 'ca', 150: '=', 151: 'boring', 152: 'gay', 153: 'yeah', 154: 'watching', 155: 'both', 156: 'never', 157: 'man', 158: 'making', 159: 'wait', 160: 'again', 161: 'â€™', 162: 'these', 163: "'re", 164: 'same', 165: 'friends', 166: 'sucked..', 167: 'always', 168: 'excellent', 169: 'person', 170: 'friday', 171: 'na', 172: 'cock', 173: 'opinion', 174: 'cool', 175: 'says', 176: 'anyone', 177: 'him', 178: 'side', 179: 'rocks', 180: 'take', 181: 'anyway', 182: 'make', 183: 'either', 184: 'worth', 185: 's', 186: 'knows', 187: 'mom', 188: 'around', 189: 'fun', 190: 'where', 191: 'community', 192: 'wanted', 193: 'care', 194: 'main', 195: 'thats', 196: 'b', 197: 'dad', 198: 'character', 199: 'review', 200: 'hates', 201: 'freakin', 202: 'daniel', 203: 'luv', 204: 'place', 205: 'cowboy', 206: 'begin', 207: 'seen..', 208: 'gon', 209: 'needs', 210: 'hat', 211: 'stand', 212: 'soo', 213: 'horrible..', 214: 'dies', 215: 'reality', 216: 'table', 217: 'acceptable', 218: 'turned', 219: 'crazy', 220: 'becoming', 221: 'awards', 222: 'past', 223: 'snuck', 224: 'head', 225: 'type', 226: 'bitch', 227: 'joining', 228: 'combining', 229: 'gin', 230: 'desperately', 231: 'keys', 232: 'hung', 233: 'virgin', 234: 'escapades', 235: 'lubb', 236: 'outshines', 237: 'groaning', 238: 'malfoy', 239: 'jane', 240: 'wotshisface', 241: 'hill', 242: 'zen', 243: 'rock-hard', 244: 'throat', 245: 'differently', 246: 'acne', 247: 'cleaning', 248: 'station', 249: 'quiz', 250: 'laughed', 251: 'despised', 252: 'aching', 253: 'bobbypin', 254: 'noises', 255: 'dash', 256: 'kelsie', 257: 'bye..', 258: 'grabs', 259: 'leah', 260: 'hoot', 261: 'mtv', 262: 'kate', 263: 'whimpering', 264: 'blonds', 265: 'trousers', 266: 'reminded', 267: 'count', 268: 'suicides', 269: 'retarted', 270: 'sit', 271: 'jokes..', 272: "'yeah", 273: 'kirsten', 274: 'slap', 275: 'catcher', 276: 'plain', 277: 'homosexuality', 278: '2.5', 279: 'draco', 280: 'dudeee', 281: 'letting', 282: 'black', 283: 'goin', 284: 'dragged', 285: "love'the", 286: 'serious', 287: 'profound', 288: 'hella', 289: "'..", 290: 'helped', 291: 'deep', 292: 'likes', 293: 'panting', 294: 'vigor', 295: 'bonkers', 296: 'gary', 297: 'hips', 298: 'insanely', 299: ' ...

# %% [markdown]
# ### Now pad the sentences to the maxlength and create the dataset for splitting

# %%
xs , ys = [], []
fin = open(INPUT_FILE, "r")
for line in fin:
    label, sent = line.strip().split("\t")
    ys.append(int(label))
    words = [x.lower() for x in nltk.word_tokenize(sent)]
    wids = [word2index[word] for word in words]
    xs.append(wids)
fin.close()
X = pad_sequences(xs, maxlen=maxlen)
Y = np_utils.to_categorical(ys)

# %% [markdown]
# ### Split the X and y to train and validation set using sklearn

# %%
#print(maxlen) # 42 in this case
# print(X.shape) # (7086 , 42) is the shape
# print(Y.shape)  # (7086, 2) is the shape
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state=42)

# %% [markdown]
# ### Now define the model and compile the model and fit the model on the train data

# %%
model = Sequential()
model.add(Embedding(vocab_size, EMBEDDING_SIZE, input_length=maxlen))
model.add(SpatialDropout1D(DROPOUT_RATE))
model.add(Conv1D(filters=NUM_FILTERS, kernel_size=NUM_WORDS, activation="relu"))
model.add(GlobalMaxPooling1D())
model.add(Dense(2, activation="softmax"))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 42, 100)           233000
# _________________________________________________________________
# spatial_dropout1d_3 (Spatial (None, 42, 100)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 40, 256)           77056
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 310,570
# Trainable params: 310,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
# have the model compile and fit on the training data

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
history = model.fit(X_train, Y_train, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS, validation_data=(X_test, Y_test))
# Out:
# Train on 4960 samples, validate on 2126 samples
# Epoch 1/20
# 4960/4960 [==============================] - 3s - loss: 6.5000e-04 - acc: 0.9998 - val_loss: 0.0252 - val_acc: 0.9939
# Epoch 2/20
# 4960/4960 [==============================] - 3s - loss: 9.1719e-04 - acc: 0.9998 - val_loss: 0.0254 - val_acc: 0.9939
# Epoch 3/20
# 4960/4960 [==============================] - 4s - loss: 0.0021 - acc: 0.9996 - val_loss: 0.0253 - val_acc: 0.9939
# Epoch 4/20
# 4960/4960 [==============================] - 4s - loss: 0.0010 - acc: 0.9998 - val_loss: 0.0276 - val_acc: 0.9929
# Epoch 5/20
# 4960/4960 [==============================] - 4s - loss: 0.0013 - acc: 0.9998 - val_loss: 0.0268 - val_acc: 0.9925
# Epoch 6/20
# 4960/4960 [==============================] - 4s - loss: 7.3826e-04 - acc: 0.9998 - val_loss: 0.0262 - val_acc: 0.9934
# Epoch 7/20
# 4960/4960 [==============================] - 4s - loss: 9.8499e-04 - acc: 0.9998 - val_loss: 0.0302 - val_acc: 0.9929
# Epoch 8/20
# 4960/4960 [==============================] - 4s - loss: 0.0019 - acc: 0.9996 - val_loss: 0.0236 - val_acc: 0.9939
# Epoch 9/20
# 4960/4960 [==============================] - 4s - loss: 6.3909e-04 - acc: 0.9998 - val_loss: 0.0244 - val_acc: 0.9934
# Epoch 10/20
# 4960/4960 [==============================] - 4s - loss: 7.8628e-04 - acc: 0.9998 - val_loss: 0.0269 - val_acc: 0.9925
# Epoch 11/20
# 4960/4960 [==============================] - 4s - loss: 0.0012 - acc: 0.9996 - val_loss: 0.0288 - val_acc: 0.9925
# Epoch 12/20
# 4960/4960 [==============================] - 3s - loss: 8.3453e-04 - acc: 0.9998 - val_loss: 0.0259 - val_acc: 0.9929
# Epoch 13/20
# 4960/4960 [==============================] - 4s - loss: 5.2666e-04 - acc: 0.9998 - val_loss: 0.0257 - val_acc: 0.9929
# Epoch 14/20
# 4960/4960 [==============================] - 4s - loss: 5.9892e-04 - acc: 0.9998 - val_loss: 0.0251 - val_acc: 0.9934
# Epoch 15/20
# 4960/4960 [==============================] - 4s - loss: 0.0016 - acc: 0.9996 - val_loss: 0.0246 - val_acc: 0.9934
# Epoch 16/20
# 4960/4960 [==============================] - 4s - loss: 7.9961e-04 - acc: 0.9998 - val_loss: 0.0253 - val_acc: 0.9925
# Epoch 17/20
# 4960/4960 [==============================] - 4s - loss: 0.0011 - acc: 0.9996 - val_loss: 0.0240 - val_acc: 0.9929
# Epoch 18/20
# 4960/4960 [==============================] - 4s - loss: 0.0012 - acc: 0.9998 - val_loss: 0.0239 - val_acc: 0.9934
# Epoch 19/20
# 4960/4960 [==============================] - 4s - loss: 1.9156e-04 - acc: 0.9998 - val_loss: 0.0246 - val_acc: 0.9934
# Epoch 20/20
# 4960/4960 [==============================] - 4s - loss: 6.3889e-04 - acc: 0.9996 - val_loss: 0.0247 - val_acc: 0.9929

# %%
#plot loss function

plt.subplot(211)
plt.title("Accuracy")
plt.plot(history.history["acc"], color="r", label="train")
plt.plot(history.history["val_acc"], color="b", label="validation")
plt.legend(loc="best")

plt.subplot(212)
plt.title("Loss")
plt.plot(history.history["loss"], color="r", label="train")
plt.plot(history.history["val_loss"], color="b", label="validation")
plt.legend(loc="best")

plt.tight_layout()
plt.show()

# %%
# check the accuracy and the loss on the test set
score = model.evaluate(X_test, Y_test, verbose=1)
print(score)
# Out:
# 2048/2126 [===========================>..] - ETA: 0s[0.024659918369843624, 0.99294449670743179]
